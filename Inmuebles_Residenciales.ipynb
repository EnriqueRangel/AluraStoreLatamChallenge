# %% [markdown]
# <a href="https://colab.research.google.com/github/EnriqueRangel/AluraStoreLatamChallenge/blob/main/Inmuebles_Residenciales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Reporte de analisis III

# %% [markdown]
# ### #Inmuebles Residenciales

# %%
import pandas as pd

# %%
datos = pd.read_csv('alquiler.csv', sep = ';', encoding = "latin-1")
datos.head(10)
# Out:
#            Tipo     Distrito  Cuartos  Vacantes  Suites  Area   Valor  \
# 0  Departamento    San Borja        1         0       0    15   800.0
# 1  Departamento   Lurigancho        1         0       0    48   800.0
# 2  Departamento          Ate        2         0       0    50  1300.0
# 3  Departamento   Pachacámac        2         1       0    70  1500.0
# 4  Departamento     Barranco        3         1       1    90  1500.0
# 5  Departamento        Comas        1         0       1    40  2000.0
# 6  Departamento  El Agustino        3         0       0    54   950.0
# 7  Departamento      Mi Perú        2         1       1    67  1700.0
# 8  Departamento   Chorrillos        2         1       0   110  1900.0
# 9  Departamento     San Luis        3         1       0    68  1000.0
#
#    Mantenimiento  Impuesto  Valor m2 Tipo Agrupado
# 0          390.0      20.0     53.33  Departamento
# 1          230.0       0.0     16.67  Departamento
# ...

# %%
list(datos['Tipo'].drop_duplicates())
# Out:
# ['Departamento', 'Casa', 'Casa en condominio', 'Casa de villa', 'Habitación']

# %%
residencial = ['Departamento', 'Casa', 'Casa en condominio', 'Casa de villa', 'Habitación']
residencial
# Out:
# ['Departamento', 'Casa', 'Casa en condominio', 'Casa de villa', 'Habitación']

# %%
datos.head(10)
# Out:
#            Tipo     Distrito  Cuartos  Vacantes  Suites  Area   Valor  \
# 0  Departamento    San Borja        1         0       0    15   800.0
# 1  Departamento   Lurigancho        1         0       0    48   800.0
# 2  Departamento          Ate        2         0       0    50  1300.0
# 3  Departamento   Pachacámac        2         1       0    70  1500.0
# 4  Departamento     Barranco        3         1       1    90  1500.0
# 5  Departamento        Comas        1         0       1    40  2000.0
# 6  Departamento  El Agustino        3         0       0    54   950.0
# 7  Departamento      Mi Perú        2         1       1    67  1700.0
# 8  Departamento   Chorrillos        2         1       0   110  1900.0
# 9  Departamento     San Luis        3         1       0    68  1000.0
#
#    Mantenimiento  Impuesto  Valor m2 Tipo Agrupado
# 0          390.0      20.0     53.33  Departamento
# 1          230.0       0.0     16.67  Departamento
# ...

# %%
seleccion = datos['Tipo'].isin(residencial)
seleccion
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 19826    True
# 19827    True
# 19828    True
# 19829    True
# 19830    True
# Name: Tipo, Length: 19831, dtype: bool

# %%
datos_residencial = datos[seleccion]
datos_residencial
# Out:
#                Tipo           Distrito  Cuartos  Vacantes  Suites  Area  \
# 0      Departamento          San Borja        1         0       0    15
# 1      Departamento         Lurigancho        1         0       0    48
# 2      Departamento                Ate        2         0       0    50
# 3      Departamento         Pachacámac        2         1       0    70
# 4      Departamento           Barranco        3         1       1    90
# ...             ...                ...      ...       ...     ...   ...
# 19826    Habitación            Mi Perú        1         0       0    10
# 19827    Habitación  Santiago de Surco        1         0       0    23
# 19828    Habitación          San Borja        1         0       0    24
# 19829    Habitación              Comas        1         0       0    22
# 19830    Habitación          San Borja        0         0       0    27
#
#         Valor  Mantenimiento  Impuesto  Valor m2 Tipo Agrupado
# ...

# %%
list(datos_residencial['Tipo'].drop_duplicates())
# Out:
# ['Departamento', 'Casa', 'Casa en condominio', 'Casa de villa', 'Habitación']

# %%
datos_residencial.shape[0]
# Out:
# 19831

# %%
datos.shape[0]
# Out:
# 19831

# %%
datos_residencial.index = range(datos_residencial.shape[0])
datos_residencial
# Out:
#                Tipo           Distrito  Cuartos  Vacantes  Suites  Area  \
# 0      Departamento          San Borja        1         0       0    15
# 1      Departamento         Lurigancho        1         0       0    48
# 2      Departamento                Ate        2         0       0    50
# 3      Departamento         Pachacámac        2         1       0    70
# 4      Departamento           Barranco        3         1       1    90
# ...             ...                ...      ...       ...     ...   ...
# 19826    Habitación            Mi Perú        1         0       0    10
# 19827    Habitación  Santiago de Surco        1         0       0    23
# 19828    Habitación          San Borja        1         0       0    24
# 19829    Habitación              Comas        1         0       0    22
# 19830    Habitación          San Borja        0         0       0    27
#
#         Valor  Mantenimiento  Impuesto  Valor m2 Tipo Agrupado
# ...

# %% [markdown]
# #Exportando la base de datos

# %%
datos_residencial.to_csv('alquiler_residencial.csv', sep = ';')

# %%
datos_residencial_2 = pd.read_csv('alquiler_residencial.csv', sep = ';', encoding = "latin-1" )
datos_residencial_2
# Out:
#        Unnamed: 0          Tipo           Distrito  Cuartos  Vacantes  Suites  \
# 0               0  Departamento          San Borja        1         0       0
# 1               1  Departamento         Lurigancho        1         0       0
# 2               2  Departamento                Ate        2         0       0
# 3               3  Departamento        PachacÃ¡mac        2         1       0
# 4               4  Departamento           Barranco        3         1       1
# ...           ...           ...                ...      ...       ...     ...
# 19826       19826   HabitaciÃ³n           Mi PerÃº        1         0       0
# 19827       19827   HabitaciÃ³n  Santiago de Surco        1         0       0
# 19828       19828   HabitaciÃ³n          San Borja        1         0       0
# 19829       19829   HabitaciÃ³n              Comas        1         0       0
# 19830       19830   HabitaciÃ³n          San Borja        0         0       0
#
# ...

# %%
datos_residencial.to_csv('alquiler_residencial.csv', sep = ';',encoding = "latin-1", index = False)

# %%
datos_residencial_2 = pd.read_csv('alquiler_residencial.csv', sep = ';', encoding = "latin-1" )
datos_residencial_2
# Out:
#                Tipo           Distrito  Cuartos  Vacantes  Suites  Area  \
# 0      Departamento          San Borja        1         0       0    15
# 1      Departamento         Lurigancho        1         0       0    48
# 2      Departamento                Ate        2         0       0    50
# 3      Departamento         Pachacámac        2         1       0    70
# 4      Departamento           Barranco        3         1       1    90
# ...             ...                ...      ...       ...     ...   ...
# 19826    Habitación            Mi Perú        1         0       0    10
# 19827    Habitación  Santiago de Surco        1         0       0    23
# 19828    Habitación          San Borja        1         0       0    24
# 19829    Habitación              Comas        1         0       0    22
# 19830    Habitación          San Borja        0         0       0    27
#
#         Valor  Mantenimiento  Impuesto  Valor m2 Tipo Agrupado
# ...
